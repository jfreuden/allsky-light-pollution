# %%
import pandas as pd
allsky = pd.read_csv('allsky.csv')
allsky
# Out:
#       Unnamed: 0        Date      Time Exposure Time (s)  \
# 0              0  2019/08/31  23:58:09           49.4054
# 1              1  2019/09/01  00:00:12           49.4054
# 2              2  2019/09/01  00:02:08           49.4054
# 3              3  2019/09/01  00:04:02           49.4054
# 4              4  2019/09/01  00:05:57           49.4054
# ...          ...         ...       ...               ...
# 9484        9484  2019/09/30  23:47:24           34.8602
# 9485        9485  2019/09/30  23:49:22           34.8602
# 9486        9486  2019/09/30  23:51:20           34.8602
# 9487        9487  2019/09/30  23:53:18           34.8602
# 9488        9488  2019/09/30  23:55:17           34.8602
#
#      Average Pixel Brightness               File Number
# 0       [106.8, 106.8, 106.8]  AllSkyImage001456621.JPG
# 1       [105.2, 105.2, 105.2]  AllSkyImage001456622.JPG
# 2       [106.4, 106.4, 106.4]  AllSkyImage001456623.JPG
# ...

# %%
from datetime import datetime

import pandas as pd
print(type(allsky.loc[0, 'Time']))


allsky['datetime'] = pd.to_datetime(allsky['Date'] + ' ' + allsky['Time'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 7
#       3 import pandas as pd
#       4 print(type(allsky.loc[0, 'Time']))
# ----> 7 allsky['datetime'] = pd.to_datetime(allsky['Date'] + ' ' + allsky['Time'])
#
# File ~\AppData\Roaming\JetBrains\DataSpell2025.3\projects\workspace\.venv\Lib\site-packages\pandas\core\tools\datetimes.py:1040, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, origin, cache)
#    1038         result = arg.map(cache_array)
#    1039     else:
# -> 1040         values = convert_listlike(arg._values, format)
#    1041         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1042 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# ...

# %%
allsky = allsky.copy()
allsky
