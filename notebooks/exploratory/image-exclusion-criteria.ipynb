# %%
import numpy as np
import dask.array as da
import dask.dataframe as dd
import pandas as pd
import dask
from PIL import Image
from dask.array.image import imread
filename_pattern = r'/home/rainybyte/AllSkyImages/2010-08/*.JPG'
images = imread(filename_pattern)
images
# Out:
# dask.array<imread, shape=(8595, 480, 640, 3), dtype=uint8, chunksize=(1, 480, 640, 3), chunktype=numpy.ndarray>

# %% [markdown]
# The objective here is to use the methods at my disposal to exclude images that are not suitable for analysis. In this instance, we are concentrating on methods that do not require parsing or OCR of the images we have.

# %%
from dask_image import ndfilters, ndmeasure, ndmorph
test_image = images[0].compute()
Image.fromarray(test_image)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480>

# %%
other_bad_image = imread(r'/home/rainybyte/AllSkyImages/2012-08/AllSkyImage000339641.JPG').compute()[0]
Image.fromarray(other_bad_image)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480>

# %%
good_image = imread(r'/home/rainybyte/AllSkyImages/2017-06/AllSkyImage001161529.JPG').compute()[0]
Image.fromarray(good_image)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480>
